# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import re
import pickle

# !pip install termcolor
from termcolor import colored, cprint

import nltk
nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger', 'wordnet'])

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk import pos_tag
from nltk.corpus import stopwords

from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier

import warnings

warnings.simplefilter('ignore')
# Out:
# Requirement already satisfied: termcolor in /Users/Saleh/anaconda3/lib/python3.7/site-packages (1.1.0)
# [nltk_data] Downloading package punkt to /Users/Saleh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Saleh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/Saleh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /Users/Saleh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# load data from database

def load_data():
    engine = create_engine('sqlite:///disaster_messages.db')
    df = pd.read_sql_table('Messages', engine)
    X = df.message
    y = df.drop(['id', 'message', 'original'], axis=1)
    return X, y
print(X.sample(1))
y.sample(1)
# Out:
# 24371    With this generous donation confirmed we will ...
# Name: message, dtype: object
#        related  request  offer  aid_related  medical_help  medical_products  \
# 24115        1        0      0            1             0                 0
#
#        search_and_rescue  security  military  water  ...  weather_related  \
# 24115                  0         0         1      0  ...                0
#
#        floods  storm  fire  earthquake  cold  other_weather  direct_report  \
# 24115       0      0     0           0     0              0              0
#
#        direct  news
# 24115       0     1
#
# [1 rows x 37 columns]

# %% [markdown]
# ---
# ### 2. Write a tokenization function to process your text data
#
# ---

# %%
def tokenize(text):
    # Normalize text
    text = re.sub(r'[^a-zA-Z0-9]', ' ', text.lower())

    # tokenize text
    tokens = word_tokenize(text)
    
    # initiate lemmatizer
    lemmatizer = WordNetLemmatizer()

    # iterate through each token
    clean_tokens = []
    for tok in tokens:
        
        # lemmatize, normalize case, and remove leading/trailing white space
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ---
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.
#
# ---

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)), 
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier())) # this strategy consists of fitting one classifier per target.
])

# %% [markdown]
# ---
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline
#
# ---

# %%
X, y = load_data()
X_train, X_test, y_train, y_test = train_test_split(X, y)
 
# train classifier
model = pipeline.fit(X_train, y_train)
model
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip..._score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=None))])

# %% [markdown]
# ---
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each. [Source for using classification_report](http://joshlawman.com/metrics-classification-report-breakdown-precision-recall-f1/)
#
# ---

# %%
def classifaction_report(model, X_test, y_test):
    # predict on test data
    y_pred = model.predict(X_test)
    
    # listing the columns
    columns = list(np.array(y.columns))
    for i, col in enumerate(columns):
        target_names = [col+'_0', col+'_1']
        print ('\nClassification Report for the column ({}):\n'.format(colored(col, 'blue', attrs=['bold', 'underline'])), 
               classification_report(y_test[col],
                                     y_pred[:, i],
                                     target_names=target_names))

# %%
classifaction_report_1 = classifaction_report(model, X_test, y_test)
classifaction_report_1
# Out:
# Classification Report for the column (related):
#                precision    recall  f1-score   support
#
#    related_0       0.62      0.36      0.46      1483
#    related_1       0.83      0.94      0.88      5024
#
#    micro avg       0.80      0.80      0.80      6507
#    macro avg       0.73      0.65      0.67      6507
# weighted avg       0.78      0.80      0.78      6507
#
#
# Classification Report for the column (request):
#                precision    recall  f1-score   support
#
#    request_0       0.88      0.98      0.93      5362
#    request_1       0.84      0.39      0.53      1145
#
#    micro avg       0.88      0.88      0.88      6507
#    macro avg       0.86      0.69      0.73      6507
# weighted avg       0.88      0.88      0.86      6507
#
#
# Classification Report for the column (offer):
#                precision    recall  f1-score   support
#
#      offer_0       1.00      1.00      1.00      6476
#      offer_1       0.00      0.00      0.00        31
#
#    micro avg       1.00      1.00      1.00      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      1.00      0.99      6507
#
#
# Classification Report for the column (aid_related):
#                 precision    recall  f1-score   support
#
# aid_related_0       0.74      0.87      0.80      3834
# aid_related_1       0.75      0.57      0.65      2673
#
#     micro avg       0.74      0.74      0.74      6507
#     macro avg       0.74      0.72      0.72      6507
#  weighted avg       0.74      0.74      0.74      6507
#
#
# Classification Report for the column (medical_help):
#                  precision    recall  f1-score   support
#
# medical_help_0       0.92      0.99      0.96      5968
# medical_help_1       0.57      0.09      0.15       539
#
#      micro avg       0.92      0.92      0.92      6507
#      macro avg       0.75      0.54      0.55      6507
#   weighted avg       0.89      0.92      0.89      6507
#
#
# Classification Report for the column (medical_products):
#                      precision    recall  f1-score   support
#
# medical_products_0       0.95      1.00      0.97      6178
# medical_products_1       0.54      0.08      0.14       329
#
#          micro avg       0.95      0.95      0.95      6507
#          macro avg       0.75      0.54      0.56      6507
#       weighted avg       0.93      0.95      0.93      6507
#
#
# Classification Report for the column (search_and_rescue):
#                       precision    recall  f1-score   support
#
# search_and_rescue_0       0.98      1.00      0.99      6364
# search_and_rescue_1       0.62      0.14      0.23       143
#
#           micro avg       0.98      0.98      0.98      6507
#           macro avg       0.80      0.57      0.61      6507
#        weighted avg       0.97      0.98      0.97      6507
#
#
# Classification Report for the column (security):
#                precision    recall  f1-score   support
#
#   security_0       0.98      1.00      0.99      6404
#   security_1       0.00      0.00      0.00       103
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.97      0.98      0.98      6507
#
#
# Classification Report for the column (military):
#                precision    recall  f1-score   support
#
#   military_0       0.97      1.00      0.98      6293
#   military_1       0.66      0.09      0.16       214
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.81      0.54      0.57      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (water):
#                precision    recall  f1-score   support
#
#      water_0       0.95      1.00      0.97      6111
#      water_1       0.78      0.26      0.39       396
#
#    micro avg       0.95      0.95      0.95      6507
#    macro avg       0.87      0.63      0.68      6507
# weighted avg       0.94      0.95      0.94      6507
#
#
# Classification Report for the column (food):
#                precision    recall  f1-score   support
#
#       food_0       0.95      0.98      0.96      5786
#       food_1       0.79      0.55      0.65       721
#
#    micro avg       0.93      0.93      0.93      6507
#    macro avg       0.87      0.77      0.81      6507
# weighted avg       0.93      0.93      0.93      6507
#
#
# Classification Report for the column (shelter):
#                precision    recall  f1-score   support
#
#    shelter_0       0.93      0.99      0.96      5918
#    shelter_1       0.83      0.26      0.39       589
#
#    micro avg       0.93      0.93      0.93      6507
#    macro avg       0.88      0.63      0.68      6507
# weighted avg       0.92      0.93      0.91      6507
#
#
# Classification Report for the column (clothing):
#                precision    recall  f1-score   support
#
#   clothing_0       0.99      1.00      0.99      6408
#   clothing_1       0.56      0.05      0.09        99
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.77      0.52      0.54      6507
# weighted avg       0.98      0.98      0.98      6507
#
#
# Classification Report for the column (money):
#                precision    recall  f1-score   support
#
#      money_0       0.98      1.00      0.99      6355
#      money_1       0.60      0.02      0.04       152
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.79      0.51      0.51      6507
# weighted avg       0.97      0.98      0.97      6507
#
#
# Classification Report for the column (missing_people):
#                    precision    recall  f1-score   support
#
# missing_people_0       0.99      1.00      0.99      6428
# missing_people_1       0.00      0.00      0.00        79
#
#        micro avg       0.99      0.99      0.99      6507
#        macro avg       0.49      0.50      0.50      6507
#     weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (refugees):
#                precision    recall  f1-score   support
#
#   refugees_0       0.97      1.00      0.98      6304
#   refugees_1       0.57      0.06      0.12       203
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.77      0.53      0.55      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (death):
#                precision    recall  f1-score   support
#
#      death_0       0.96      1.00      0.98      6220
#      death_1       0.74      0.10      0.18       287
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.85      0.55      0.58      6507
# weighted avg       0.95      0.96      0.94      6507
#
#
# Classification Report for the column (other_aid):
#                precision    recall  f1-score   support
#
#  other_aid_0       0.87      1.00      0.93      5631
#  other_aid_1       0.45      0.03      0.05       876
#
#    micro avg       0.86      0.86      0.86      6507
#    macro avg       0.66      0.51      0.49      6507
# weighted avg       0.81      0.86      0.81      6507
#
#
# Classification Report for the column (infrastructure_related):
#                            precision    recall  f1-score   support
#
# infrastructure_related_0       0.93      1.00      0.96      6062
# infrastructure_related_1       0.14      0.00      0.00       445
#
#                micro avg       0.93      0.93      0.93      6507
#                macro avg       0.54      0.50      0.48      6507
#             weighted avg       0.88      0.93      0.90      6507
#
#
# Classification Report for the column (transport):
#                precision    recall  f1-score   support
#
#  transport_0       0.95      1.00      0.98      6192
#  transport_1       0.68      0.07      0.13       315
#
#    micro avg       0.95      0.95      0.95      6507
#    macro avg       0.82      0.54      0.55      6507
# weighted avg       0.94      0.95      0.94      6507
#
#
# Classification Report for the column (buildings):
#                precision    recall  f1-score   support
#
#  buildings_0       0.95      1.00      0.98      6179
#  buildings_1       0.74      0.10      0.17       328
#
#    micro avg       0.95      0.95      0.95      6507
#    macro avg       0.85      0.55      0.57      6507
# weighted avg       0.94      0.95      0.94      6507
#
#
# Classification Report for the column (electricity):
#                 precision    recall  f1-score   support
#
# electricity_0       0.98      1.00      0.99      6389
# electricity_1       0.78      0.06      0.11       118
#
#     micro avg       0.98      0.98      0.98      6507
#     macro avg       0.88      0.53      0.55      6507
#  weighted avg       0.98      0.98      0.98      6507
#
#
# Classification Report for the column (tools):
#                precision    recall  f1-score   support
#
#      tools_0       0.99      1.00      1.00      6469
#      tools_1       0.00      0.00      0.00        38
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (hospitals):
#                precision    recall  f1-score   support
#
#  hospitals_0       0.99      1.00      0.99      6434
#  hospitals_1       0.00      0.00      0.00        73
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (shops):
#                precision    recall  f1-score   support
#
#      shops_0       0.99      1.00      1.00      6472
#      shops_1       0.00      0.00      0.00        35
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (aid_centers):
#                 precision    recall  f1-score   support
#
# aid_centers_0       0.99      1.00      0.99      6422
# aid_centers_1       0.00      0.00      0.00        85
#
#     micro avg       0.99      0.99      0.99      6507
#     macro avg       0.49      0.50      0.50      6507
#  weighted avg       0.97      0.99      0.98      6507
#
#
# Classification Report for the column (other_infrastructure):
#                          precision    recall  f1-score   support
#
# other_infrastructure_0       0.95      1.00      0.98      6204
# other_infrastructure_1       0.33      0.00      0.01       303
#
#              micro avg       0.95      0.95      0.95      6507
#              macro avg       0.64      0.50      0.49      6507
#           weighted avg       0.92      0.95      0.93      6507
#
#
# Classification Report for the column (weather_related):
#                     precision    recall  f1-score   support
#
# weather_related_0       0.85      0.96      0.90      4704
# weather_related_1       0.83      0.56      0.67      1803
#
#         micro avg       0.85      0.85      0.85      6507
#         macro avg       0.84      0.76      0.79      6507
#      weighted avg       0.85      0.85      0.84      6507
#
#
# Classification Report for the column (floods):
#                precision    recall  f1-score   support
#
#     floods_0       0.94      1.00      0.97      5968
#     floods_1       0.89      0.33      0.48       539
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.92      0.66      0.73      6507
# weighted avg       0.94      0.94      0.93      6507
#
#
# Classification Report for the column (storm):
#                precision    recall  f1-score   support
#
#      storm_0       0.94      0.99      0.96      5898
#      storm_1       0.72      0.37      0.49       609
#
#    micro avg       0.93      0.93      0.93      6507
#    macro avg       0.83      0.68      0.72      6507
# weighted avg       0.92      0.93      0.92      6507
#
#
# Classification Report for the column (fire):
#                precision    recall  f1-score   support
#
#       fire_0       0.99      1.00      1.00      6443
#       fire_1       1.00      0.02      0.03        64
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       1.00      0.51      0.51      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (earthquake):
#                precision    recall  f1-score   support
#
# earthquake_0       0.97      0.99      0.98      5910
# earthquake_1       0.89      0.65      0.76       597
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.93      0.82      0.87      6507
# weighted avg       0.96      0.96      0.96      6507
#
#
# Classification Report for the column (cold):
#                precision    recall  f1-score   support
#
#       cold_0       0.98      1.00      0.99      6372
#       cold_1       0.76      0.10      0.17       135
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.87      0.55      0.58      6507
# weighted avg       0.98      0.98      0.97      6507
#
#
# Classification Report for the column (other_weather):
#                   precision    recall  f1-score   support
#
# other_weather_0       0.95      1.00      0.97      6166
# other_weather_1       0.56      0.03      0.05       341
#
#       micro avg       0.95      0.95      0.95      6507
#       macro avg       0.76      0.51      0.51      6507
#    weighted avg       0.93      0.95      0.92      6507
#
#
# Classification Report for the column (direct_report):
#                   precision    recall  f1-score   support
#
# direct_report_0       0.85      0.98      0.91      5220
# direct_report_1       0.80      0.32      0.46      1287
#
#       micro avg       0.85      0.85      0.85      6507
#       macro avg       0.83      0.65      0.69      6507
#    weighted avg       0.84      0.85      0.82      6507
#
#
# Classification Report for the column (direct):
#                precision    recall  f1-score   support
#
#     direct_0       0.95      0.94      0.94      3844
#     direct_1       0.92      0.92      0.92      2663
#
#    micro avg       0.93      0.93      0.93      6507
#    macro avg       0.93      0.93      0.93      6507
# weighted avg       0.93      0.93      0.93      6507
#
#
# Classification Report for the column (news):
#                precision    recall  f1-score   support
#
#       news_0       0.92      0.97      0.94      3273
#       news_1       0.97      0.92      0.94      3234
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.94      0.94      0.94      6507
# weighted avg       0.94      0.94      0.94      6507

# %%
def scores_report(model, X_test, y_test):
    # predict on test data
    y_pred = model.predict(X_test)
    
    # listing the columns
    columns = list(np.array(y.columns))
    for i, col in enumerate(columns):
        precision, recall, fscore, support = precision_recall_fscore_support(y_test[col],
                                                                    y_pred[:, i],
                                                                    average='weighted')
        
        print('\nReport for the column ({}):\n'.format(colored(col, 'blue', attrs=['bold', 'underline'])))
        
        if precision >= 0.75:
            print('Precision: {}'.format(colored(round(precision, 2), 'green')))
        else:
            print('Precision: {}'.format(colored(round(precision, 2), 'red')))
            
        if recall >= 0.75:
            print('Recall: {}'.format(colored(round(recall, 2), 'green')))
        else:
            print('Recall: {}'.format(colored(round(recall, 2), 'red')))
            
        if fscore >= 0.75:
            print('F-score: {}'.format(colored(round(fscore, 2), 'green')))
        else:
            print('F-score: {}'.format(colored(round(fscore, 2), 'red')))

# %%
scores_report = scores_report(model, X_test, y_test)
scores_report
# Out:
# Report for the column (related):
#
# Precision: 0.78
# Recall: 0.8
# F-score: 0.78
#
# Report for the column (request):
#
# Precision: 0.88
# Recall: 0.88
# F-score: 0.86
#
# Report for the column (offer):
#
# Precision: 0.99
# Recall: 1.0
# F-score: 0.99
#
# Report for the column (aid_related):
#
# Precision: 0.74
# Recall: 0.74
# F-score: 0.74
#
# Report for the column (medical_help):
#
# Precision: 0.89
# Recall: 0.92
# F-score: 0.89
#
# Report for the column (medical_products):
#
# Precision: 0.93
# Recall: 0.95
# F-score: 0.93
#
# Report for the column (search_and_rescue):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (security):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (military):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (water):
#
# Precision: 0.94
# Recall: 0.95
# F-score: 0.94
#
# Report for the column (food):
#
# Precision: 0.93
# Recall: 0.93
# F-score: 0.93
#
# Report for the column (shelter):
#
# Precision: 0.92
# Recall: 0.93
# F-score: 0.91
#
# Report for the column (clothing):
#
# Precision: 0.98
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (money):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (missing_people):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (refugees):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (death):
#
# Precision: 0.95
# Recall: 0.96
# F-score: 0.94
#
# Report for the column (other_aid):
#
# Precision: 0.81
# Recall: 0.86
# F-score: 0.81
#
# Report for the column (infrastructure_related):
#
# Precision: 0.88
# Recall: 0.93
# F-score: 0.9
#
# Report for the column (transport):
#
# Precision: 0.94
# Recall: 0.95
# F-score: 0.94
#
# Report for the column (buildings):
#
# Precision: 0.94
# Recall: 0.95
# F-score: 0.94
#
# Report for the column (electricity):
#
# Precision: 0.98
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (tools):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (hospitals):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (shops):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (aid_centers):
#
# Precision: 0.97
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (other_infrastructure):
#
# Precision: 0.92
# Recall: 0.95
# F-score: 0.93
#
# Report for the column (weather_related):
#
# Precision: 0.85
# Recall: 0.85
# F-score: 0.84
#
# Report for the column (floods):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.93
#
# Report for the column (storm):
#
# Precision: 0.92
# Recall: 0.93
# F-score: 0.92
#
# Report for the column (fire):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (earthquake):
#
# Precision: 0.96
# Recall: 0.96
# F-score: 0.96
#
# Report for the column (cold):
#
# Precision: 0.98
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (other_weather):
#
# Precision: 0.93
# Recall: 0.95
# F-score: 0.92
#
# Report for the column (direct_report):
#
# Precision: 0.84
# Recall: 0.85
# F-score: 0.82
#
# Report for the column (direct):
#
# Precision: 0.93
# Recall: 0.93
# F-score: 0.93
#
# Report for the column (news):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94

# %% [markdown]
# ---
# ### 6. Improve your model
# Use grid search to find better parameters.
#
# ---

# %%
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=<function tokenize at 0x1a33edb510>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False),
#               n_jobs=None))],
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize at 0x1a33edb510>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#             n_jobs=None),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__bootstrap': True,
#  'clf__estimator__class_weight': None,
#  'clf__estimator__criterion': 'gini',
#  'clf__estimator__max_depth': None,
#  'clf__estimator__max_features': 'auto',
#  'clf__estimator__max_leaf_nodes': None,
#  'clf__estimator__min_impurity_decrease': 0.0,
#  'clf__estimator__min_impurity_split': None,
#  'clf__estimator__min_samples_leaf': 1,
#  'clf__estimator__min_samples_split': 2,
#  'clf__estimator__min_weight_fraction_leaf': 0.0,
#  'clf__estimator__n_estimators': 'warn',
#  'clf__estimator__n_jobs': None,
#  'clf__estimator__oob_score': False,
#  'clf__estimator__random_state': None,
#  'clf__estimator__verbose': 0,
#  'clf__estimator__warm_start': False,
#  'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'clf__n_jobs': None}

# %%
# specify parameters for grid search
parameters = {'vect__min_df': [1, 5],
              'tfidf__use_idf': (True, False), 
              'clf__estimator__n_estimators': [10, 25], 
              'clf__estimator__min_samples_split': [2, 4]}

# create grid search object
cv = GridSearchCV(model, param_grid=parameters)
model_2 = cv.fit(X_train, y_train)

# %% [markdown]
# ---
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!
#
# ---

# %%
classifaction_report_2 = classifaction_report(model_2, X_test, y_test)
classifaction_report_2
# Out:
# Classification Report for the column (related):
#                precision    recall  f1-score   support
#
#    related_0       0.72      0.33      0.45      1483
#    related_1       0.83      0.96      0.89      5024
#
#    micro avg       0.82      0.82      0.82      6507
#    macro avg       0.77      0.64      0.67      6507
# weighted avg       0.80      0.82      0.79      6507
#
#
# Classification Report for the column (request):
#                precision    recall  f1-score   support
#
#    request_0       0.90      0.98      0.94      5362
#    request_1       0.85      0.46      0.60      1145
#
#    micro avg       0.89      0.89      0.89      6507
#    macro avg       0.87      0.72      0.77      6507
# weighted avg       0.89      0.89      0.88      6507
#
#
# Classification Report for the column (offer):
#                precision    recall  f1-score   support
#
#      offer_0       1.00      1.00      1.00      6476
#      offer_1       0.00      0.00      0.00        31
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (aid_related):
#                 precision    recall  f1-score   support
#
# aid_related_0       0.79      0.82      0.80      3834
# aid_related_1       0.73      0.68      0.70      2673
#
#     micro avg       0.76      0.76      0.76      6507
#     macro avg       0.76      0.75      0.75      6507
#  weighted avg       0.76      0.76      0.76      6507
#
#
# Classification Report for the column (medical_help):
#                  precision    recall  f1-score   support
#
# medical_help_0       0.92      0.99      0.96      5968
# medical_help_1       0.54      0.09      0.15       539
#
#      micro avg       0.92      0.92      0.92      6507
#      macro avg       0.73      0.54      0.55      6507
#   weighted avg       0.89      0.92      0.89      6507
#
#
# Classification Report for the column (medical_products):
#                      precision    recall  f1-score   support
#
# medical_products_0       0.96      1.00      0.98      6178
# medical_products_1       0.65      0.17      0.27       329
#
#          micro avg       0.95      0.95      0.95      6507
#          macro avg       0.80      0.58      0.62      6507
#       weighted avg       0.94      0.95      0.94      6507
#
#
# Classification Report for the column (search_and_rescue):
#                       precision    recall  f1-score   support
#
# search_and_rescue_0       0.98      1.00      0.99      6364
# search_and_rescue_1       0.64      0.06      0.11       143
#
#           micro avg       0.98      0.98      0.98      6507
#           macro avg       0.81      0.53      0.55      6507
#        weighted avg       0.97      0.98      0.97      6507
#
#
# Classification Report for the column (security):
#                precision    recall  f1-score   support
#
#   security_0       0.98      1.00      0.99      6404
#   security_1       0.00      0.00      0.00       103
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.97      0.98      0.98      6507
#
#
# Classification Report for the column (military):
#                precision    recall  f1-score   support
#
#   military_0       0.97      1.00      0.98      6293
#   military_1       0.58      0.10      0.17       214
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.77      0.55      0.58      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (water):
#                precision    recall  f1-score   support
#
#      water_0       0.96      0.99      0.98      6111
#      water_1       0.80      0.37      0.51       396
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.88      0.68      0.74      6507
# weighted avg       0.95      0.96      0.95      6507
#
#
# Classification Report for the column (food):
#                precision    recall  f1-score   support
#
#       food_0       0.96      0.98      0.97      5786
#       food_1       0.79      0.67      0.72       721
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.88      0.82      0.85      6507
# weighted avg       0.94      0.94      0.94      6507
#
#
# Classification Report for the column (shelter):
#                precision    recall  f1-score   support
#
#    shelter_0       0.95      0.99      0.97      5918
#    shelter_1       0.84      0.44      0.58       589
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.90      0.72      0.77      6507
# weighted avg       0.94      0.94      0.93      6507
#
#
# Classification Report for the column (clothing):
#                precision    recall  f1-score   support
#
#   clothing_0       0.99      1.00      0.99      6408
#   clothing_1       0.67      0.12      0.21        99
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.83      0.56      0.60      6507
# weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (money):
#                precision    recall  f1-score   support
#
#      money_0       0.98      1.00      0.99      6355
#      money_1       0.80      0.05      0.10       152
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.89      0.53      0.54      6507
# weighted avg       0.97      0.98      0.97      6507
#
#
# Classification Report for the column (missing_people):
#                    precision    recall  f1-score   support
#
# missing_people_0       0.99      1.00      0.99      6428
# missing_people_1       1.00      0.01      0.02        79
#
#        micro avg       0.99      0.99      0.99      6507
#        macro avg       0.99      0.51      0.51      6507
#     weighted avg       0.99      0.99      0.98      6507
#
#
# Classification Report for the column (refugees):
#                precision    recall  f1-score   support
#
#   refugees_0       0.97      1.00      0.98      6304
#   refugees_1       0.57      0.08      0.15       203
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.77      0.54      0.57      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (death):
#                precision    recall  f1-score   support
#
#      death_0       0.97      1.00      0.98      6220
#      death_1       0.78      0.30      0.43       287
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.87      0.65      0.71      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (other_aid):
#                precision    recall  f1-score   support
#
#  other_aid_0       0.87      1.00      0.93      5631
#  other_aid_1       0.56      0.04      0.07       876
#
#    micro avg       0.87      0.87      0.87      6507
#    macro avg       0.72      0.52      0.50      6507
# weighted avg       0.83      0.87      0.81      6507
#
#
# Classification Report for the column (infrastructure_related):
#                            precision    recall  f1-score   support
#
# infrastructure_related_0       0.93      1.00      0.96      6062
# infrastructure_related_1       0.40      0.00      0.01       445
#
#                micro avg       0.93      0.93      0.93      6507
#                macro avg       0.67      0.50      0.49      6507
#             weighted avg       0.90      0.93      0.90      6507
#
#
# Classification Report for the column (transport):
#                precision    recall  f1-score   support
#
#  transport_0       0.96      1.00      0.98      6192
#  transport_1       0.74      0.13      0.23       315
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.85      0.57      0.60      6507
# weighted avg       0.95      0.96      0.94      6507
#
#
# Classification Report for the column (buildings):
#                precision    recall  f1-score   support
#
#  buildings_0       0.96      1.00      0.98      6179
#  buildings_1       0.84      0.14      0.24       328
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.90      0.57      0.61      6507
# weighted avg       0.95      0.96      0.94      6507
#
#
# Classification Report for the column (electricity):
#                 precision    recall  f1-score   support
#
# electricity_0       0.98      1.00      0.99      6389
# electricity_1       0.57      0.07      0.12       118
#
#     micro avg       0.98      0.98      0.98      6507
#     macro avg       0.78      0.53      0.56      6507
#  weighted avg       0.98      0.98      0.98      6507
#
#
# Classification Report for the column (tools):
#                precision    recall  f1-score   support
#
#      tools_0       0.99      1.00      1.00      6469
#      tools_1       0.00      0.00      0.00        38
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (hospitals):
#                precision    recall  f1-score   support
#
#  hospitals_0       0.99      1.00      0.99      6434
#  hospitals_1       0.00      0.00      0.00        73
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.49      0.50      0.50      6507
# weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (shops):
#                precision    recall  f1-score   support
#
#      shops_0       0.99      1.00      1.00      6472
#      shops_1       0.00      0.00      0.00        35
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (aid_centers):
#                 precision    recall  f1-score   support
#
# aid_centers_0       0.99      1.00      0.99      6422
# aid_centers_1       0.00      0.00      0.00        85
#
#     micro avg       0.99      0.99      0.99      6507
#     macro avg       0.49      0.50      0.50      6507
#  weighted avg       0.97      0.99      0.98      6507
#
#
# Classification Report for the column (other_infrastructure):
#                          precision    recall  f1-score   support
#
# other_infrastructure_0       0.95      1.00      0.98      6204
# other_infrastructure_1       0.00      0.00      0.00       303
#
#              micro avg       0.95      0.95      0.95      6507
#              macro avg       0.48      0.50      0.49      6507
#           weighted avg       0.91      0.95      0.93      6507
#
#
# Classification Report for the column (weather_related):
#                     precision    recall  f1-score   support
#
# weather_related_0       0.90      0.94      0.92      4704
# weather_related_1       0.83      0.72      0.77      1803
#
#         micro avg       0.88      0.88      0.88      6507
#         macro avg       0.86      0.83      0.84      6507
#      weighted avg       0.88      0.88      0.88      6507
#
#
# Classification Report for the column (floods):
#                precision    recall  f1-score   support
#
#     floods_0       0.96      1.00      0.98      5968
#     floods_1       0.91      0.48      0.63       539
#
#    micro avg       0.95      0.95      0.95      6507
#    macro avg       0.93      0.74      0.80      6507
# weighted avg       0.95      0.95      0.95      6507
#
#
# Classification Report for the column (storm):
#                precision    recall  f1-score   support
#
#      storm_0       0.96      0.98      0.97      5898
#      storm_1       0.74      0.60      0.66       609
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.85      0.79      0.82      6507
# weighted avg       0.94      0.94      0.94      6507
#
#
# Classification Report for the column (fire):
#                precision    recall  f1-score   support
#
#       fire_0       0.99      1.00      1.00      6443
#       fire_1       0.50      0.06      0.11        64
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.75      0.53      0.55      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (earthquake):
#                precision    recall  f1-score   support
#
# earthquake_0       0.98      0.99      0.99      5910
# earthquake_1       0.89      0.81      0.85       597
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.94      0.90      0.92      6507
# weighted avg       0.97      0.97      0.97      6507
#
#
# Classification Report for the column (cold):
#                precision    recall  f1-score   support
#
#       cold_0       0.98      1.00      0.99      6372
#       cold_1       0.66      0.16      0.25       135
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.82      0.58      0.62      6507
# weighted avg       0.98      0.98      0.97      6507
#
#
# Classification Report for the column (other_weather):
#                   precision    recall  f1-score   support
#
# other_weather_0       0.95      1.00      0.97      6166
# other_weather_1       0.54      0.07      0.13       341
#
#       micro avg       0.95      0.95      0.95      6507
#       macro avg       0.75      0.53      0.55      6507
#    weighted avg       0.93      0.95      0.93      6507
#
#
# Classification Report for the column (direct_report):
#                   precision    recall  f1-score   support
#
# direct_report_0       0.87      0.97      0.92      5220
# direct_report_1       0.79      0.39      0.53      1287
#
#       micro avg       0.86      0.86      0.86      6507
#       macro avg       0.83      0.68      0.72      6507
#    weighted avg       0.85      0.86      0.84      6507
#
#
# Classification Report for the column (direct):
#                precision    recall  f1-score   support
#
#     direct_0       0.96      0.94      0.95      3844
#     direct_1       0.92      0.94      0.93      2663
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.94      0.94      0.94      6507
# weighted avg       0.94      0.94      0.94      6507
#
#
# Classification Report for the column (news):
#                precision    recall  f1-score   support
#
#       news_0       0.94      0.96      0.95      3273
#       news_1       0.96      0.94      0.95      3234
#
#    micro avg       0.95      0.95      0.95      6507
#    macro avg       0.95      0.95      0.95      6507
# weighted avg       0.95      0.95      0.95      6507

# %%
scores_report_2 = scores_report(model_2, X_test, y_test)
scores_report_2
# Out:
# Report for the column (related):
#
# Precision: 0.8
# Recall: 0.82
# F-score: 0.79
#
# Report for the column (request):
#
# Precision: 0.89
# Recall: 0.89
# F-score: 0.88
#
# Report for the column (offer):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (aid_related):
#
# Precision: 0.76
# Recall: 0.76
# F-score: 0.76
#
# Report for the column (medical_help):
#
# Precision: 0.89
# Recall: 0.92
# F-score: 0.89
#
# Report for the column (medical_products):
#
# Precision: 0.94
# Recall: 0.95
# F-score: 0.94
#
# Report for the column (search_and_rescue):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (security):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (military):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (water):
#
# Precision: 0.95
# Recall: 0.96
# F-score: 0.95
#
# Report for the column (food):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94
#
# Report for the column (shelter):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.93
#
# Report for the column (clothing):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (money):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (missing_people):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (refugees):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (death):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (other_aid):
#
# Precision: 0.83
# Recall: 0.87
# F-score: 0.81
#
# Report for the column (infrastructure_related):
#
# Precision: 0.9
# Recall: 0.93
# F-score: 0.9
#
# Report for the column (transport):
#
# Precision: 0.95
# Recall: 0.96
# F-score: 0.94
#
# Report for the column (buildings):
#
# Precision: 0.95
# Recall: 0.96
# F-score: 0.94
#
# Report for the column (electricity):
#
# Precision: 0.98
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (tools):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (hospitals):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (shops):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (aid_centers):
#
# Precision: 0.97
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (other_infrastructure):
#
# Precision: 0.91
# Recall: 0.95
# F-score: 0.93
#
# Report for the column (weather_related):
#
# Precision: 0.88
# Recall: 0.88
# F-score: 0.88
#
# Report for the column (floods):
#
# Precision: 0.95
# Recall: 0.95
# F-score: 0.95
#
# Report for the column (storm):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94
#
# Report for the column (fire):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (earthquake):
#
# Precision: 0.97
# Recall: 0.97
# F-score: 0.97
#
# Report for the column (cold):
#
# Precision: 0.98
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (other_weather):
#
# Precision: 0.93
# Recall: 0.95
# F-score: 0.93
#
# Report for the column (direct_report):
#
# Precision: 0.85
# Recall: 0.86
# F-score: 0.84
#
# Report for the column (direct):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94
#
# Report for the column (news):
#
# Precision: 0.95
# Recall: 0.95
# F-score: 0.95

# %%
model_2.best_params_
# Out:
# {'clf__estimator__min_samples_split': 4,
#  'clf__estimator__n_estimators': 25,
#  'tfidf__use_idf': True,
#  'vect__min_df': 5}

# %% [markdown]
# ---
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF
#
# ---

# %%
pipeline_2 = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(AdaBoostClassifier()))
])

pipeline_2.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=None, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('clf',
#    MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#              learning_rate=1.0, n_estimators=50, random_state=None),
#               n_jobs=None))],
#  'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=None, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'clf': MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#            learning_rate=1.0, n_estimators=50, random_state=None),
#             n_jobs=None),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': None,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__algorithm': 'SAMME.R',
#  'clf__estimator__base_estimator': None,
#  'clf__estimator__learning_rate': 1.0,
#  'clf__estimator__n_estimators': 50,
#  'clf__estimator__random_state': None,
#  'clf__estimator': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#            learning_rate=1.0, n_estimators=50, random_state=None),
#  'clf__n_jobs': None}

# %%
# train classifier
model_3 = pipeline_2.fit(X_train, y_train)
model_3
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...or=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#            n_jobs=None))])

# %%
classifaction_report_3 = classifaction_report(model_3, X_test, y_test)
classifaction_report_3
# Out:
# Classification Report for the column (related):
#                precision    recall  f1-score   support
#
#    related_0       0.68      0.25      0.37      1483
#    related_1       0.81      0.97      0.88      5024
#
#    micro avg       0.80      0.80      0.80      6507
#    macro avg       0.75      0.61      0.63      6507
# weighted avg       0.78      0.80      0.77      6507
#
#
# Classification Report for the column (request):
#                precision    recall  f1-score   support
#
#    request_0       0.91      0.97      0.94      5362
#    request_1       0.78      0.54      0.64      1145
#
#    micro avg       0.89      0.89      0.89      6507
#    macro avg       0.85      0.76      0.79      6507
# weighted avg       0.89      0.89      0.89      6507
#
#
# Classification Report for the column (offer):
#                precision    recall  f1-score   support
#
#      offer_0       1.00      1.00      1.00      6476
#      offer_1       0.00      0.00      0.00        31
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (aid_related):
#                 precision    recall  f1-score   support
#
# aid_related_0       0.75      0.86      0.80      3834
# aid_related_1       0.75      0.60      0.67      2673
#
#     micro avg       0.75      0.75      0.75      6507
#     macro avg       0.75      0.73      0.73      6507
#  weighted avg       0.75      0.75      0.75      6507
#
#
# Classification Report for the column (medical_help):
#                  precision    recall  f1-score   support
#
# medical_help_0       0.94      0.98      0.96      5968
# medical_help_1       0.61      0.28      0.39       539
#
#      micro avg       0.93      0.93      0.93      6507
#      macro avg       0.78      0.63      0.67      6507
#   weighted avg       0.91      0.93      0.91      6507
#
#
# Classification Report for the column (medical_products):
#                      precision    recall  f1-score   support
#
# medical_products_0       0.96      0.99      0.98      6178
# medical_products_1       0.62      0.32      0.42       329
#
#          micro avg       0.96      0.96      0.96      6507
#          macro avg       0.79      0.65      0.70      6507
#       weighted avg       0.95      0.96      0.95      6507
#
#
# Classification Report for the column (search_and_rescue):
#                       precision    recall  f1-score   support
#
# search_and_rescue_0       0.98      1.00      0.99      6364
# search_and_rescue_1       0.53      0.20      0.29       143
#
#           micro avg       0.98      0.98      0.98      6507
#           macro avg       0.75      0.60      0.64      6507
#        weighted avg       0.97      0.98      0.97      6507
#
#
# Classification Report for the column (security):
#                precision    recall  f1-score   support
#
#   security_0       0.98      1.00      0.99      6404
#   security_1       0.06      0.01      0.02       103
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.52      0.50      0.50      6507
# weighted avg       0.97      0.98      0.98      6507
#
#
# Classification Report for the column (military):
#                precision    recall  f1-score   support
#
#   military_0       0.98      0.99      0.98      6293
#   military_1       0.58      0.29      0.39       214
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.78      0.64      0.69      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (water):
#                precision    recall  f1-score   support
#
#      water_0       0.98      0.99      0.98      6111
#      water_1       0.75      0.63      0.69       396
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.87      0.81      0.84      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (food):
#                precision    recall  f1-score   support
#
#       food_0       0.96      0.98      0.97      5786
#       food_1       0.79      0.69      0.74       721
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.87      0.83      0.85      6507
# weighted avg       0.94      0.94      0.94      6507
#
#
# Classification Report for the column (shelter):
#                precision    recall  f1-score   support
#
#    shelter_0       0.96      0.98      0.97      5918
#    shelter_1       0.76      0.54      0.63       589
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.86      0.76      0.80      6507
# weighted avg       0.94      0.94      0.94      6507
#
#
# Classification Report for the column (clothing):
#                precision    recall  f1-score   support
#
#   clothing_0       0.99      1.00      0.99      6408
#   clothing_1       0.67      0.31      0.43        99
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.83      0.66      0.71      6507
# weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (money):
#                precision    recall  f1-score   support
#
#      money_0       0.98      0.99      0.99      6355
#      money_1       0.53      0.26      0.35       152
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.76      0.63      0.67      6507
# weighted avg       0.97      0.98      0.97      6507
#
#
# Classification Report for the column (missing_people):
#                    precision    recall  f1-score   support
#
# missing_people_0       0.99      1.00      0.99      6428
# missing_people_1       0.73      0.20      0.32        79
#
#        micro avg       0.99      0.99      0.99      6507
#        macro avg       0.86      0.60      0.66      6507
#     weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (refugees):
#                precision    recall  f1-score   support
#
#   refugees_0       0.98      0.99      0.98      6304
#   refugees_1       0.48      0.23      0.31       203
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.73      0.61      0.65      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (death):
#                precision    recall  f1-score   support
#
#      death_0       0.97      0.99      0.98      6220
#      death_1       0.75      0.41      0.53       287
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.86      0.70      0.76      6507
# weighted avg       0.96      0.97      0.96      6507
#
#
# Classification Report for the column (other_aid):
#                precision    recall  f1-score   support
#
#  other_aid_0       0.88      0.98      0.93      5631
#  other_aid_1       0.54      0.17      0.26       876
#
#    micro avg       0.87      0.87      0.87      6507
#    macro avg       0.71      0.58      0.60      6507
# weighted avg       0.84      0.87      0.84      6507
#
#
# Classification Report for the column (infrastructure_related):
#                            precision    recall  f1-score   support
#
# infrastructure_related_0       0.94      0.99      0.96      6062
# infrastructure_related_1       0.51      0.12      0.19       445
#
#                micro avg       0.93      0.93      0.93      6507
#                macro avg       0.73      0.55      0.58      6507
#             weighted avg       0.91      0.93      0.91      6507
#
#
# Classification Report for the column (transport):
#                precision    recall  f1-score   support
#
#  transport_0       0.96      0.99      0.98      6192
#  transport_1       0.70      0.27      0.39       315
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.83      0.63      0.68      6507
# weighted avg       0.95      0.96      0.95      6507
#
#
# Classification Report for the column (buildings):
#                precision    recall  f1-score   support
#
#  buildings_0       0.97      0.99      0.98      6179
#  buildings_1       0.72      0.39      0.51       328
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.84      0.69      0.74      6507
# weighted avg       0.96      0.96      0.96      6507
#
#
# Classification Report for the column (electricity):
#                 precision    recall  f1-score   support
#
# electricity_0       0.99      1.00      0.99      6389
# electricity_1       0.73      0.32      0.45       118
#
#     micro avg       0.99      0.99      0.99      6507
#     macro avg       0.86      0.66      0.72      6507
#  weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (tools):
#                precision    recall  f1-score   support
#
#      tools_0       0.99      1.00      1.00      6469
#      tools_1       0.14      0.03      0.04        38
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.57      0.51      0.52      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (hospitals):
#                precision    recall  f1-score   support
#
#  hospitals_0       0.99      1.00      0.99      6434
#  hospitals_1       0.33      0.12      0.18        73
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.66      0.56      0.59      6507
# weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (shops):
#                precision    recall  f1-score   support
#
#      shops_0       0.99      1.00      1.00      6472
#      shops_1       0.00      0.00      0.00        35
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.50      0.50      0.50      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (aid_centers):
#                 precision    recall  f1-score   support
#
# aid_centers_0       0.99      1.00      0.99      6422
# aid_centers_1       0.31      0.09      0.14        85
#
#     micro avg       0.99      0.99      0.99      6507
#     macro avg       0.65      0.55      0.57      6507
#  weighted avg       0.98      0.99      0.98      6507
#
#
# Classification Report for the column (other_infrastructure):
#                          precision    recall  f1-score   support
#
# other_infrastructure_0       0.96      0.99      0.97      6204
# other_infrastructure_1       0.28      0.07      0.11       303
#
#              micro avg       0.95      0.95      0.95      6507
#              macro avg       0.62      0.53      0.54      6507
#           weighted avg       0.92      0.95      0.93      6507
#
#
# Classification Report for the column (weather_related):
#                     precision    recall  f1-score   support
#
# weather_related_0       0.88      0.96      0.92      4704
# weather_related_1       0.86      0.66      0.75      1803
#
#         micro avg       0.88      0.88      0.88      6507
#         macro avg       0.87      0.81      0.83      6507
#      weighted avg       0.87      0.88      0.87      6507
#
#
# Classification Report for the column (floods):
#                precision    recall  f1-score   support
#
#     floods_0       0.96      0.99      0.98      5968
#     floods_1       0.86      0.58      0.70       539
#
#    micro avg       0.96      0.96      0.96      6507
#    macro avg       0.91      0.79      0.84      6507
# weighted avg       0.96      0.96      0.95      6507
#
#
# Classification Report for the column (storm):
#                precision    recall  f1-score   support
#
#      storm_0       0.95      0.98      0.97      5898
#      storm_1       0.77      0.54      0.64       609
#
#    micro avg       0.94      0.94      0.94      6507
#    macro avg       0.86      0.76      0.80      6507
# weighted avg       0.94      0.94      0.94      6507
#
#
# Classification Report for the column (fire):
#                precision    recall  f1-score   support
#
#       fire_0       0.99      1.00      1.00      6443
#       fire_1       0.52      0.17      0.26        64
#
#    micro avg       0.99      0.99      0.99      6507
#    macro avg       0.76      0.59      0.63      6507
# weighted avg       0.99      0.99      0.99      6507
#
#
# Classification Report for the column (earthquake):
#                precision    recall  f1-score   support
#
# earthquake_0       0.98      0.99      0.98      5910
# earthquake_1       0.88      0.79      0.83       597
#
#    micro avg       0.97      0.97      0.97      6507
#    macro avg       0.93      0.89      0.91      6507
# weighted avg       0.97      0.97      0.97      6507
#
#
# Classification Report for the column (cold):
#                precision    recall  f1-score   support
#
#       cold_0       0.99      1.00      0.99      6372
#       cold_1       0.67      0.38      0.48       135
#
#    micro avg       0.98      0.98      0.98      6507
#    macro avg       0.83      0.69      0.74      6507
# weighted avg       0.98      0.98      0.98      6507
#
#
# Classification Report for the column (other_weather):
#                   precision    recall  f1-score   support
#
# other_weather_0       0.95      0.99      0.97      6166
# other_weather_1       0.47      0.12      0.19       341
#
#       micro avg       0.95      0.95      0.95      6507
#       macro avg       0.71      0.56      0.58      6507
#    weighted avg       0.93      0.95      0.93      6507
#
#
# Classification Report for the column (direct_report):
#                   precision    recall  f1-score   support
#
# direct_report_0       0.88      0.96      0.92      5220
# direct_report_1       0.73      0.49      0.58      1287
#
#       micro avg       0.86      0.86      0.86      6507
#       macro avg       0.81      0.72      0.75      6507
#    weighted avg       0.85      0.86      0.85      6507
#
#
# Classification Report for the column (direct):
#                precision    recall  f1-score   support
#
#     direct_0       0.90      0.93      0.92      3844
#     direct_1       0.90      0.85      0.87      2663
#
#    micro avg       0.90      0.90      0.90      6507
#    macro avg       0.90      0.89      0.90      6507
# weighted avg       0.90      0.90      0.90      6507
#
#
# Classification Report for the column (news):
#                precision    recall  f1-score   support
#
#       news_0       0.93      0.90      0.92      3273
#       news_1       0.90      0.93      0.92      3234
#
#    micro avg       0.92      0.92      0.92      6507
#    macro avg       0.92      0.92      0.92      6507
# weighted avg       0.92      0.92      0.92      6507

# %%
scores_report_3 = scores_report(model_3, X_test, y_test)
scores_report_3
# Out:
# Report for the column (related):
#
# Precision: 0.78
# Recall: 0.8
# F-score: 0.77
#
# Report for the column (request):
#
# Precision: 0.89
# Recall: 0.89
# F-score: 0.89
#
# Report for the column (offer):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (aid_related):
#
# Precision: 0.75
# Recall: 0.75
# F-score: 0.75
#
# Report for the column (medical_help):
#
# Precision: 0.91
# Recall: 0.93
# F-score: 0.91
#
# Report for the column (medical_products):
#
# Precision: 0.95
# Recall: 0.96
# F-score: 0.95
#
# Report for the column (search_and_rescue):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (security):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (military):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (water):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (food):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94
#
# Report for the column (shelter):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94
#
# Report for the column (clothing):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (money):
#
# Precision: 0.97
# Recall: 0.98
# F-score: 0.97
#
# Report for the column (missing_people):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (refugees):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (death):
#
# Precision: 0.96
# Recall: 0.97
# F-score: 0.96
#
# Report for the column (other_aid):
#
# Precision: 0.84
# Recall: 0.87
# F-score: 0.84
#
# Report for the column (infrastructure_related):
#
# Precision: 0.91
# Recall: 0.93
# F-score: 0.91
#
# Report for the column (transport):
#
# Precision: 0.95
# Recall: 0.96
# F-score: 0.95
#
# Report for the column (buildings):
#
# Precision: 0.96
# Recall: 0.96
# F-score: 0.96
#
# Report for the column (electricity):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (tools):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (hospitals):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (shops):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (aid_centers):
#
# Precision: 0.98
# Recall: 0.99
# F-score: 0.98
#
# Report for the column (other_infrastructure):
#
# Precision: 0.92
# Recall: 0.95
# F-score: 0.93
#
# Report for the column (weather_related):
#
# Precision: 0.87
# Recall: 0.88
# F-score: 0.87
#
# Report for the column (floods):
#
# Precision: 0.96
# Recall: 0.96
# F-score: 0.95
#
# Report for the column (storm):
#
# Precision: 0.94
# Recall: 0.94
# F-score: 0.94
#
# Report for the column (fire):
#
# Precision: 0.99
# Recall: 0.99
# F-score: 0.99
#
# Report for the column (earthquake):
#
# Precision: 0.97
# Recall: 0.97
# F-score: 0.97
#
# Report for the column (cold):
#
# Precision: 0.98
# Recall: 0.98
# F-score: 0.98
#
# Report for the column (other_weather):
#
# Precision: 0.93
# Recall: 0.95
# F-score: 0.93
#
# Report for the column (direct_report):
#
# Precision: 0.85
# Recall: 0.86
# F-score: 0.85
#
# Report for the column (direct):
#
# Precision: 0.9
# Recall: 0.9
# F-score: 0.9
#
# Report for the column (news):
#
# Precision: 0.92
# Recall: 0.92
# F-score: 0.92

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
f = 'model.pkl'
pickle.dump(model_2, open(f, 'wb'))

# Open the file to save as pkl file
model_pkl = open(f, 'wb')
pickle.dump(model_2, model_pkl)
# Close the pickle instances
decision_tree_model_pkl.close()

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
